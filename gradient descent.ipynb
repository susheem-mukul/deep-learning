# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(-1,1,0.001)
def func(x):
    f=x**8+x**7+x**4+x**5-x
    return f
def diff(x):
    df=8*x**7+4*x**3+5*x**4-1+7*x**6
    return df

# %%
plt.plot(x,f)

# %%
rate=0.0001
c=-0.75
acc=0.1
s=1
while s>0.00000001:
    p=c
    c=c-rate*diff(p)
    s=abs(p-c)

# %%
plt.plot(x,f)
plt.plot(c,func(c),'r+')
